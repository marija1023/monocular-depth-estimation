# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/'My Drive'/ML/Projekat
# !ls
# Out:
# /content/drive/My Drive/ML/Projekat
# data  kitti_utils.py  load_datasets  ml_proj.ipynb

# %% [markdown]
# # **Mono Dataset**

# %%
from __future__ import absolute_import, division, print_function

import os
import random
import numpy as np
import copy
from PIL import Image  # using pillow-simd for increased speed

import torch
import torch.utils.data as data
from torchvision import transforms

# %%
data_path = '/content/drive/My Drive/ML/Projekat/data/photos/2011_09_26_drive_0005_sync/image_02/data/0000000000.png'

# %%
def pil_loader(path):
    # open path as file to avoid ResourceWarning
    # (https://github.com/python-pillow/Pillow/issues/835)
    with open(path, 'rb') as f:
        with Image.open(f) as img:
            return img.convert('RGB')

# %%
pil_loader(data_path)
# Out:
# <PIL.Image.Image image mode=RGB size=1242x375 at 0x7F72EFA39710>

# %%
# !python datasets/mono_dataset.py

# %% [markdown]
# # **KITTI Dataset**

# %%
# !python3 datasets/kitti_dataset.py
