# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/'My Drive'/ML/Projekat/monocular-depth-estimation
# !ls
# Out:
# /content/drive/My Drive/ML/Projekat/monocular-depth-estimation
# data			     kitti_dataset.py	 mono_dataset.py    splits
# depth_decoder.py	     kitti_loader.ipynb  pose_cnn.py	    trainer.py
# depth_estimation_test.ipynb  kitti_utils.py	 __pycache__	    train.py
# evaluate_depth.py	     layers.py		 README.md	    utils.py
# export_gt_depth.py	     models		 resnet_encoder.py

# %%
# !pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 317kB 9.4MB/s
# ...

# %% [markdown]
# Pokretanje faze za treniranje.

# %%
# !python3 train.py
# Out:
# Training model named:
#    model
# Models and tensorboard events files are saved to:
#    /content/drive/My Drive/ML/Projekat/monocular-depth-estimation/models
# Training is using:
#    cuda
# There are 199 training items and 51 validation items
#
# EPOHA
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:123: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# Training
# ...

# %%
# !python3 export_gt_depth.py
# Out:
# Exporting ground truth depths
# Saving to split

# %%
# !python3 evaluate_depth.py
# Out:
# -> Computing predictions with size 640x192
# -> Evaluating
#
#    abs_rel |   sq_rel |     rmse | rmse_log |       a1 |       a2 |       a3 |
# &   1.000  &  18.223  &  22.561  &   8.938  &   0.000  &   0.000  &   0.000  \\
#
# -> Done!

# %% [markdown]
# Cuvanje izgenerisanih slika dubine.

# %%
# !python3 test.py
